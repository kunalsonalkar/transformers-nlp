# %%
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
## Read the file from URL 
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df = pd.read_csv(url,sep='\t')

# %%
## First 5 records
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
## Last 7 Records 
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
## Total Records 
df.info()
df.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# 4622

# %%
#Which was the most ordered item? and How many items were ordered?
c = df.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'],ascending = False)

# %%
c.head()
# Out:
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506
# Steak Burrito          328437       386
# Canned Soft Drink      304753       351

# %%
#What was the most ordered item in the choice_description column?
choice_desc = df.groupby('choice_description')
choice_desc = choice_desc.sum()
choice_desc = choice_desc.sort_values(['quantity'],ascending = False)

# %%
choice_desc.head()
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42

# %%
dollar = lambda x: float(x[1:-1])
df.item_price = df.item_price.apply(dollar)

# %%
df[1:-1]
# Out:
#       order_id  quantity                              item_name  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4616      1832         1                    Chips and Guacamole
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv',index_col='Respondent')

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
### Setting to Display all the columns 
pd.set_option('display.max_columns',85)
### Setting to display all rows
pd.set_option('display.max_rows',85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df.head(10)
# Out:
#                                                      QuestionText
# Column
# Respondent      Randomized respondent ID number (not in order ...
# MainBranch      Which of the following options best describes ...
# Hobbyist                                  Do you code as a hobby?
# OpenSourcer           How often do you contribute to open source?
# OpenSource      How do you feel about the quality of open sour...
# Employment      Which of the following best describes your cur...
# Country                 In which country do you currently reside?
# Student         Are you currently enrolled in a formal, degree...
# EdLevel         Which of the following best describes the high...
# UndergradMajor  What was your main or most important field of ...

# %%
people = {
    "first": ["Corey","Jane","John","Chris",np.nan, None, "NA"],
    "last": ["Schafer","Doe","Doe","Schafer",np.nan,np.nan,"Missing"],
    "email": ["coreymschafer@gmail.com","janedoe@gmail.com","johndoe@gmail.com",None,np.nan,"anonymous@email.com","NA"],
    "age": ['33','55','63','36','None','None','Missing']
}

# %%
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
## This is series object which has a lot more functionality than just lists/ ( Rows of single column )
df2['email']
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@gmail.com
# 2          johndoe@gmail.com
# Name: email, dtype: object

# %%
type(df2['email'])
# Out:
# pandas.core.series.Series

# %%
df2[['last','email']]
# Out:
#       last                    email
# 0  Schafer  coreymschafer@gmail.com
# 1      Doe        janedoe@gmail.com
# 2      Doe        johndoe@gmail.com

# %%
### loc and iloc (integer location) indexers
### Primarily used for accessing rows 
df2.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    coreymschafer@gmail.com
# Name: 0, dtype: object

# %%
df2.iloc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com

# %%
## We can add column number as well in iloc
df2.iloc[[0,1],2]
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@gmail.com
# Name: email, dtype: object

# %%
## with loc we will search by labels 
df2.loc[[0,1],['email','last']]
# Out:
#                      email     last
# 0  coreymschafer@gmail.com  Schafer
# 1        janedoe@gmail.com      Doe

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
## First 3 results of Hobbyist  to Employment column 
df2.loc[]
# Out:
#   File "<ipython-input-54-fb1e346531f6>", line 2
#     df2.loc[]
#             ^
# SyntaxError: invalid syntax

# %%
## This wont change the df2 value unless you set the inplace parameter to true. 
df2.set_index('email',inplace=True)
df2
# Out:
#                          first     last
# email
# coreymschafer@gmail.com  Corey  Schafer
# janedoe@gmail.com         Jane      Doe
# johndoe@gmail.com         John      Doe

# %%
## df2.loc[0] won't work. 
df2.loc['coreymschafer@gmail.com']
df2.loc['coreymschafer@gmail.com','last']
# Out:
# 'Schafer'

# %%
df2.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: coreymschafer@gmail.com, dtype: object

# %%
df2.reset_index(inplace = True)

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2        johndoe@gmail.com   John      Doe

# %%
schema_df.loc['ConvertedComp','QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index()
schema_df.sort_index(ascending = False)
schema_df.sort_index(inplace=True)

# %%
### Filtering Data, 'filter is the key word, so i used filt'
filt = df2['last'] == 'Doe'
filt2 = (df2['last'] == 'Doe') & (df2['first'] == 'John')
filt3 = (df2['last'] == 'Schafer') | (df2['first'] == 'John')

# %%
df2[filt]
# Out:
#                email first last
# 1  janedoe@gmail.com  Jane  Doe
# 2  johndoe@gmail.com  John  Doe

# %%
df2.loc[filt2]
df2.loc[filt2,'email']
# Out:
# 2    johndoe@gmail.com
# Name: email, dtype: object

# %%
### 1st is row, 2nd argument is column
df2.loc[filt,'email']
# Out:
# 1    janedoe@gmail.com
# 2    johndoe@gmail.com
# Name: email, dtype: object

# %%
df2.loc[filt3]
df2.loc[filt3,'email']
# Out:
# 0    coreymschafer@gmail.com
# 2          johndoe@gmail.com
# Name: email, dtype: object

# %%
## ~ sign negates the filter 
df2.loc[~filt3,'email']
# Out:
# 1    janedoe@gmail.com
# Name: email, dtype: object

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countires = ['United States','India','United Kingdom','Germany','Canada']
filt_country = df['Country'].isin(countires)

# %%
df.loc[filt_country,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt_language = df['LanguageWorkedWith'].str.contains('Python',na = False)
df.loc[filt_language,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
### Alter the data techniques 
df2.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df2.columns = ['email','first_name','last_name']

# %%
df2.columns
# Out:
# Index(['email', 'first_name', 'last_name'], dtype='object')

# %%
## Upper Case
df2.columns = [x.upper() for x in df2.columns]

# %%
df2.columns
# Out:
# Index(['EMAIL', 'FIRST_NAME', 'LAST_NAME'], dtype='object')

# %%
df2.columns = df2.columns.str.replace(' ','_')

# %%
df2.columns
# Out:
# Index(['EMAIL', 'FIRST_NAME', 'LAST_NAME'], dtype='object')

# %%
## you have to use inplace for letting this change go through 
df2.rename(columns={'FIRST_NAME':'first','LAST_NAME':'last','EMAIL':'email'},inplace= True)

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2        johndoe@gmail.com   John      Doe

# %%
## Change last name from Doe to Smith 
df2.loc[2]
# Out:
# email    johndoe@gmail.com
# first                 John
# last                   Doe
# Name: 2, dtype: object

# %%
df2.loc[2] = ['johnsmith@email.com','Smith','John']

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com  Smith     John

# %%
## Change only one Cell Value
df2.loc[2,'last'] = 'Wayne'

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com  Smith    Wayne

# %%
df2.at[2,'last'] = 'Doe'
df2.at[2,'first'] = 'John'

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com   John      Doe

# %%
### This wont work !!! Value gets set on temproary object. Better use loc or at command 
filt_lastname = (df2['email'] == 'johnsmith@email.com')
df2[filt_lastname]
df2[filt_lastname]['laast'] = 'Smith'
# Out:
# <ipython-input-98-ebbde0bc3322>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[filt_lastname]['laast'] = 'Smith'

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com   John      Doe

# %%
df2.loc[filt_lastname, 'last'] = 'Smith'

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com   John    Smith

# %%
## email address to lower case 
df2['email'] = df2['email'].str.lower()

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com   John    Smith

# %%
## apply, map, applymap, replace 
## 1. apply - used to call a function on series or dataframe
df2['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    19
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df2['email'] = df2['email'].apply(update_email)

# %%
df2
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   Jane      Doe
# 2      JOHNSMITH@EMAIL.COM   John    Smith

# %%
df2['email'] = df2['email'].apply(lambda x: x.lower())

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2      johnsmith@email.com   John    Smith

# %%
## Means every row has these many columns
df2.apply(len,axis = 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df2['email'])
# Out:
# 3

# %%
## Running apply on a series applies the function to every value in the series 
## Running apply on dataframe applies the function to every series in the dataframe 
df2.apply(pd.Series.min)
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
## applymap works only for dattaframe
df2.applymap(len)
# Out:
#    email  first  last
# 0     23      5     7
# 1     17      4     3
# 2     19      4     5

# %%
df2.applymap(str.lower)
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  corey  schafer
# 1        janedoe@gmail.com   jane      doe
# 2      johnsmith@email.com   john    smith

# %%
## Map works on series only. For example substituting value with another value
## Gets NaN value with old entries, so better use replace function for this.
df2['first'].map({'Corey':'Chris','Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df2['first'] =df2['first'].replace({'Corey':'Chris','Jane':'Mary'})

# %%
df2
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Chris  Schafer
# 1        janedoe@gmail.com   Mary      Doe
# 2      johnsmith@email.com   John    Smith

# %%
df.rename(columns = {'ConvertedComp': 'SalaryUSD'},inplace=True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No': False})

# %%
### Adding Columns 
df2['first']+ ' ' +df2['last']
# Out:
# 0    Chris Schafer
# 1         Mary Doe
# 2       John Smith
# dtype: object

# %%
df2['full_name'] = df2['first']+ ' ' +df2['last']

# %%
df2.drop(columns = ['first','last'],inplace=True)

# %%
df2
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Chris Schafer
# 1        janedoe@gmail.com       Mary Doe
# 2      johnsmith@email.com     John Smith

# %%
## String Split, Put 'expand = true' and it will give two columns 
df2['full_name'].str.split(' ',expand = True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Mary      Doe
# 2   John    Smith

# %%
df2[['first','last']] = df2['full_name'].str.split(' ',expand = True)

# %%
df2
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2      johnsmith@email.com     John Smith   John    Smith

# %%
df2.append({'first':'Tony'},ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2      johnsmith@email.com     John Smith   John    Smith
# 3                      NaN            NaN   Tony      NaN

# %%
people = {
    "first": ["Tony","Steve"],
    "last": ["Stark","Rogers"],
    "email": ["ironman@gmail.com","cap@gmail.com"]
}

# %%
df3 = pd.DataFrame(people)

# %%
df3
# Out:
#    first    last              email
# 0   Tony   Stark  ironman@gmail.com
# 1  Steve  Rogers      cap@gmail.com

# %%
df2 = df2.append(df3,ignore_index=True)

# %%
df2
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2      johnsmith@email.com     John Smith   John    Smith
# 3        ironman@gmail.com            NaN   Tony    Stark
# 4            cap@gmail.com            NaN  Steve   Rogers

# %%
## Removing Rows 
df2.drop(index =4)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2      johnsmith@email.com     John Smith   John    Smith
# 3        ironman@gmail.com            NaN   Tony    Stark

# %%
## Remove last Name Doe 
last_name_doe = df2['last']=='Doe'

# %%
df2.drop(index=df2[last_name_doe].index)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2      johnsmith@email.com     John Smith   John    Smith
# 3        ironman@gmail.com            NaN   Tony    Stark
# 4            cap@gmail.com            NaN  Steve   Rogers

# %%
df2.sort_values(by=['last','first'],ascending=False)
# Out:
#                      email      full_name  first     last
# 3        ironman@gmail.com            NaN   Tony    Stark
# 2      johnsmith@email.com     John Smith   John    Smith
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 4            cap@gmail.com            NaN  Steve   Rogers
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe

# %%
### Sorting data in Pandas
df2
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John      Doe        johndoe@gmail.com

# %%
df2.sort_values(by='last',ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John      Doe        johndoe@gmail.com

# %%
df2.sort_values(by=['last','first'],ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 2   John      Doe        johndoe@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 3   Adam      Doe              a@email.com

# %%
## Sorting by descending for last name but ascending for first name 
df2.sort_values(by=['last','first'],ascending=[False,True],inplace=True)

# %%
df2
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 3   Adam      Doe              a@email.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John      Doe        johndoe@gmail.com

# %%
## Sorting it back
df2.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John      Doe        johndoe@gmail.com
# 3   Adam      Doe              a@email.com

# %%
df2['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending=[True,False],inplace=True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df[['Country','ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 28638       Afghanistan            0.0
# 722         Afghanistan            0.0
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# 63019       Afghanistan            NaN
# 6417        Afghanistan            NaN
# 40000       Afghanistan            NaN
# 88731       Afghanistan            NaN
# 62525       Afghanistan            NaN
# 49702       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 60946       Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
## Largest Salaries. You can use nsmallest as well for  lowest salaries.
df.nlargest(10,'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df['ConvertedComp'].head()
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
## count is the non missing values
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 2940        I am a developer by profession      Yes
# 3133        I am a developer by profession      Yes
# 78960       I am a developer by profession      Yes
# 3120        I am a developer by profession      Yes
# 78853       I am a developer by profession       No
# ...                                    ...      ...
# 32801       I am a developer by profession       No
# 32811       I am a developer by profession       No
# 32886       I am a developer by profession       No
# 68604       I am a developer by profession      Yes
# 33792       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts(normalize = True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['United States']
# Out:
# 110000.0

# %%
country_grp['ConvertedComp'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
 
country_grp

# %%
## How many people know Python
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
## We are running an apply function series group
## One way of finding percentage of people who know
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize = True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Chad                         1
# North Korea                  1
# Saint Kitts and Nevis        1
# Sao Tome and Principe        1
# Papua New Guinea             1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis = 'columns',sort = False)

# %%
python_df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Chad                         1                   0
# North Korea                  1                   0
# Saint Kitts and Nevis        1                   0
# Sao Tome and Principe        1                   1
# Papua New Guinea             1                   0
#
# [179 rows x 2 columns]

# %%
## Rename columns so that they make more sense
python_df.rename(columns = {'Country': 'NumRespondents','LanguageWorkedWith': 'NumKnowsPython'},inplace=True)

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython
# United States                   20949           10083
# India                            9061            3105
# Germany                          5866            2451
# United Kingdom                   5737            2384
# Canada                           3395            1558
# ...                               ...             ...
# Chad                                1               0
# North Korea                         1               0
# Saint Kitts and Nevis               1               0
# Sao Tome and Principe               1               1
# Papua New Guinea                    1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython  PctKnowsPython
# United States                   20949           10083       48.131176
# India                            9061            3105       34.267741
# Germany                          5866            2451       41.783157
# United Kingdom                   5737            2384       41.554820
# Canada                           3395            1558       45.891016
# ...                               ...             ...             ...
# Chad                                1               0        0.000000
# North Korea                         1               0        0.000000
# Saint Kitts and Nevis               1               0        0.000000
# Sao Tome and Principe               1               1      100.000000
# Papua New Guinea                    1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython',ascending = False)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Dominica                                       1               1
# Timor-Leste                                    1               1
# Niger                                          1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Lao People's Democratic Republic               3               0
# Cape Verde                                     3               0
# Liberia                                        2               0
# Malawi                                         2               0
# Papua New Guinea                               1               0
#
#                                   PctKnowsPython
# Sao Tome and Principe                 100.000000
# Dominica                              100.000000
# ...

# %%
## Data with Missing Values
df2
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
### axis can be set to index or columns, "How argument" - drop any rows with NA values in it 
df2.dropna(axis = 'index',how ='any')
df2.dropna(axis = 'index',how ='all') ## All values have to be missing for this to work.
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2.dropna(axis = 'index', how = 'any', subset = ['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 5   None      NaN      anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2.dropna(axis = 'index', how = 'all', subset = ['last','email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  coreymschafer@gmail.com       33
# 1   Jane      Doe        janedoe@gmail.com       55
# 2   John      Doe        johndoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
##3 Replace the custom missing values with NA
df2.replace('NA',np.nan, inplace=True)
df2.replace('Missing',np.nan, inplace=True)

# %%
df2
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  coreymschafer@gmail.com    33
# 1   Jane      Doe        janedoe@gmail.com    55
# 2   John      Doe        johndoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df2.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  coreymschafer@gmail.com  33
# 1   Jane      Doe        janedoe@gmail.com  55
# 2   John      Doe        johndoe@gmail.com  63

# %%
df2.dropna(axis = 'index', how = 'all', subset = ['last','email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  coreymschafer@gmail.com    33
# 1   Jane      Doe        janedoe@gmail.com    55
# 2   John      Doe        johndoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      anonymous@email.com  None

# %%
## This will just give a mask for which values will be treated as NAs 
df2.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True  False
# 5   True   True  False  False
# 6   True   True   True   True

# %%
df2.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  coreymschafer@gmail.com       33
# 1     Jane      Doe        janedoe@gmail.com       55
# 2     John      Doe        johndoe@gmail.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING     None
# 5  MISSING  MISSING      anonymous@email.com     None
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
 df2
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  coreymschafer@gmail.com    33
# 1   Jane      Doe        janedoe@gmail.com    55
# 2   John      Doe        johndoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN
